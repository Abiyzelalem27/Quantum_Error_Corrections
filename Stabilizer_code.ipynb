# %%
# %pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from quantum_error_corrections import (
    
    I, X, Y, Z, H, P0, P1, I8, X1, X2, X3,
Z1, Z2, Z3, ghz_minus, ghz_plus, phase_stabilizer_1, phase_stabilizer_2, 
ket0, ket1, ket_plus, three_qubit_zero, apply_error, measure_stabilizer, 
three_qubit_one, shor_logical_zero, U_N_qubits, shor_logical_one,
bit_stabilizer_1a, bit_stabilizer_1b, bit_stabilizer_2a, correct_errors,  
bit_stabilizer_2b, bit_stabilizer_3a, bit_stabilizer_3b, detect_errors 
)

# %%
import numpy as np
logical_zero = shor_logical_zero()
logical_one  = shor_logical_one()
zero3 = three_qubit_zero()
one3  = three_qubit_one()

# Print Results
print("Three-Qubit |000⟩:\n", zero3)
print()
print("Three-Qubit |111⟩:\n", one3)
print()
print("Shape Logical |0⟩_L:", logical_zero.shape)
print()
print("Shape Logical |1⟩_L:", logical_one.shape)
print()
print("Norm Logical |0⟩_L:", np.linalg.norm(logical_zero))
print()
print("Norm Logical |1⟩_L:", np.linalg.norm(logical_one))
# Out:
# Three-Qubit |000⟩:
#  [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#
# Three-Qubit |111⟩:
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#
# Shape Logical |0⟩_L: (512,)
#
# Shape Logical |1⟩_L: (512,)
#
# Norm Logical |0⟩_L: 0.9999999999999998
#
# Norm Logical |1⟩_L: 0.9999999999999998

# %%
import numpy as np

# Prepare logical states first
logical_zero_state = shor_logical_zero()  
logical_one_state  = shor_logical_one() 

# Apply a no error on qubit 
state =logical_zero_state

# Apply stabilizers
S1 = phase_stabilizer_1()
S2 = phase_stabilizer_2()
# Measure stabilizers
m1 = measure_stabilizer(state, S1)
m2 = measure_stabilizer(state, S2)

print("stabilizer:")
print("(S1, S2) =", (m1, m2))
print()

if m1 == -1 and m2 == +1:
    print("Z error detected in Block 1 (qubits 1-3)")
elif m1 == -1 and m2 == -1:
    print("Z error detected in Block 2 (qubits 4-6)")
elif m1 == +1 and m2 == -1:
    print("Z error detected in Block 3 (qubits 7-9)")
else:
    print("No phase error detected")
# Out:
# stabilizer:
# (S1, S2) = (1, 1)
#
# No phase error detected

# %%
# Prepare logical states first
logical_zero= shor_logical_zero()  
logical_one= shor_logical_one()   

# Apply a Z error on qubit 9
state = apply_error(logical_zero, Z, 0, 9)
S1 = phase_stabilizer_1()
S2 = phase_stabilizer_2()

m1 = measure_stabilizer(state, S1)
m2 = measure_stabilizer(state, S2)

print("Phase stabilizer measurements for state:")
print("(S1, S2) =", (m1, m2))
print()

if m1 == -1 and m2 == +1:
    print(" error in Block 1")
elif m1 == -1 and m2 == -1:
    print("error in Block 2 ")
elif m1 == +1 and m2 == -1:
    print("error in Block 3 ")
else:
    print("No phase error")
# Out:
# Phase stabilizer measurements for state:
# (S1, S2) = (-1, 1)
#
#  error in Block 1

# %%
# Prepare logical states first
logical_zero_state = shor_logical_zero()  
logical_one_state  = shor_logical_one()   

# Apply a Z error on qubit 1
state = apply_error(logical_one, Z, 1, 9)

# Apply stabilizers
S1 = phase_stabilizer_1()
S2 = phase_stabilizer_2()

# Measure stabilizers
m1 = measure_stabilizer(state, S1)
m2 = measure_stabilizer(state, S2)

print("stabilizer:")
print("(S1, S2) =", (m1, m2))
print()

if m1 == -1 and m2 == +1:
    print("Z error detected in Block 1 (qubits 1-3)")
elif m1 == -1 and m2 == -1:
    print("Z error detected in Block 2 (qubits 4-6)")
elif m1 == +1 and m2 == -1:
    print("Z error detected in Block 3 (qubits 7-9)")
else:
    print("No phase error detected")
# Out:
# stabilizer:
# (S1, S2) = (-1, 1)
#
# Z error detected in Block 1 (qubits 1-3)

# %%
   # Prepare logical states first
logical_zero= shor_logical_zero()  
logical_one= shor_logical_one()   

# Apply a Z error on qubit 2
state = apply_error(logical_one, Z, 2, 9)

S1 = phase_stabilizer_1()
S2 = phase_stabilizer_2()
m1 = measure_stabilizer(state, S1)
m2 = measure_stabilizer(state, S2)

print("stabilizer:")
print("(S1, S2) =", (m1 , m2))
print()

if m1 == -1 and m2 == +1:
    print(" error in Block 1")
elif m1 == -1 and m2 == -1:
    print("error in Block 2 ")
elif m1 == +1 and m2 == -1:
    print("error in Block 3 ")
else:
    print("No phase error")
# Out:
# stabilizer:
# (S1, S2) = (-1, 1)
#
#  error in Block 1

# %%
# Prepare logical states first
logical_zero= shor_logical_zero()  
logical_one= shor_logical_one()   

# Apply a Z error on qubit 3
state = apply_error(logical_zero, Z, 3,  9)

S1 = phase_stabilizer_1()
S2 = phase_stabilizer_2()

m1 = measure_stabilizer(state, S1)
m2 = measure_stabilizer(state, S2)

print("Phase stabilizer:")
print("(S1 , S2) =", (m1 , m2))
print()

if m1 == -1 and m2 == +1:
    print(" error in Block 1")
elif m1 == -1 and m2 == -1:
    print("error in Block 2 ")
elif m1 == +1 and m2 == -1:
    print("error in Block 3 ")
else:
    print("No phase error")
# Out:
# Phase stabilizer:
# (S1 , S2) = (-1, -1)
#
# error in Block 2

# %%
# Prepare logical states first
logical_zero= shor_logical_zero()  
logical_one= shor_logical_one()   

# Apply a Z error on qubit 4
state = apply_error(logical_zero, Z, 4, 9)
S1 = phase_stabilizer_1()
S2 = phase_stabilizer_2()

m1 = measure_stabilizer(state, S1)
m2 = measure_stabilizer(state, S2)

print("Phase stabilizer measurements for state:")
print("(S1, S2) =", (m1, m2))
print()

if m1 == -1 and m2 == +1:
    print(" error in Block 1")
elif m1 == -1 and m2 == -1:
    print("error in Block 2 ")
elif m1 == +1 and m2 == -1:
    print("error in Block 3 ")
else:
    print("No phase error")
# Out:
# Phase stabilizer measurements for state:
# (S1, S2) = (-1, -1)
#
# error in Block 2

# %%
# Prepare logical states first
logical_zero= shor_logical_zero()  
logical_one= shor_logical_one()   

# Apply a Z error on qubit 5
state = apply_error(logical_zero, Z, 5, 9)
S1 = phase_stabilizer_1()
S2 = phase_stabilizer_2()

m1 = measure_stabilizer(state, S1)
m2 = measure_stabilizer(state, S2)

print("Phase stabilizer measurements for state:")
print("(S1, S2) =", (m1, m2))
print()

if m1 == -1 and m2 == +1:
    print(" error in Block 1")
elif m1 == -1 and m2 == -1:
    print("error in Block 2 ")
elif m1 == +1 and m2 == -1:
    print("error in Block 3 ")
else:
    print("No phase error")
# Out:
# Phase stabilizer measurements for state:
# (S1, S2) = (-1, -1)
#
# error in Block 2

# %%
# Prepare logical states first
logical_zero= shor_logical_zero()  
logical_one= shor_logical_one()   

# Apply a Z error on qubit 6 
state = apply_error(logical_zero, Z, 6, 9)
S1 = phase_stabilizer_1()
S2 = phase_stabilizer_2()

m1 = measure_stabilizer(state, S1)
m2 = measure_stabilizer(state, S2)

print("Phase stabilizer measurements for state:")
print("(S1, S2) =", (m1, m2))
print()

if m1 == -1 and m2 == +1:
    print(" error in Block 1")
elif m1 == -1 and m2 == -1:
    print("error in Block 2 ")
elif m1 == +1 and m2 == -1:
    print("error in Block 3 ")
else:
    print("No phase error")
# Out:
# Phase stabilizer measurements for state:
# (S1, S2) = (1, -1)
#
# error in Block 3

# %%
# Prepare logical states first
logical_zero= shor_logical_zero()  
logical_one= shor_logical_one()   

# Apply a Z error on qubit 7
state = apply_error(logical_zero, Z, 7, 9)
S1 = phase_stabilizer_1()
S2 = phase_stabilizer_2()

m1 = measure_stabilizer(state, S1)
m2 = measure_stabilizer(state, S2)

print("Phase stabilizer measurements for state:")
print("(S1, S2) =", (m1, m2))
print()

if m1 == -1 and m2 == +1:
    print(" error in Block 1")
elif m1 == -1 and m2 == -1:
    print("error in Block 2 ")
elif m1 == +1 and m2 == -1:
    print("error in Block 3 ")
else:
    print("No phase error")
# Out:
# Phase stabilizer measurements for state:
# (S1, S2) = (1, -1)
#
# error in Block 3

# %%
# Prepare logical states first
logical_zero= shor_logical_zero()  
logical_one= shor_logical_one()   

# Apply a Z error on qubit 8
state = apply_error(logical_zero, Z, 8, 9)
S1 = phase_stabilizer_1()
S2 = phase_stabilizer_2()

m1 = measure_stabilizer(state, S1)
m2 = measure_stabilizer(state, S2)

print("Phase stabilizer measurements for state:")
print("(S1, S2) =", (m1, m2))
print()

if m1 == -1 and m2 == +1:
    print(" error in Block 1")
elif m1 == -1 and m2 == -1:
    print("error in Block 2 ")
elif m1 == +1 and m2 == -1:
    print("error in Block 3 ")
else:
    print("No phase error")
# Out:
# Phase stabilizer measurements for state:
# (S1, S2) = (1, -1)
#
# error in Block 3
