# %%
# %pip install numpy matplotlib
# %pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from quantum_error_corrections import (
    I, X, Y, Z, H, P0, P1, I8, X1, X2, X3, Z1, Z2, Z3, E1_rho,  bit_flip_kraus_nqubits, 
    U_N_qubits, U_one_gate, U_two_gates, controlled_gate, rotation_gate,
    rho, evolve, recovery_bit_flip, depolarizing_kraus_nqubits, correct_phase_flip,  
    recovery_phase_flip, initial_state, apply_hadamards, normalize_state, 
    projectors, born_rule_probs, sample_from_probs, single_qubit_channel_n_register, 
    measure_pure_state, measurement_density_matrix, 
    measure_probs_first_n, sample_measurements_input, sample_probs, rotation_channel, 
    bit_flip_kraus, phase_flip_kraus, amplitude_damping_kraus, encode_3_qubit_phase_flip_code, 
    phase_damping_kraus, depolarizing_kraus, pauli_kraus_channel, bit_flip_channel_3qubits, syndrome_measurement_bit_flip,  
    apply_channel, apply_kraus, E1_rho, bloch_visualization, correct_bit_flip, syndrome_measurement_phase_flip, 
    dm, random_pure_state, ket0, ket1, ket_plus, bloch_vector, encode_3_qubit_bit_flip_code, ket_minus, apply_kraus_sparse, 
    buildSparseGateSingle, buildSparseCNOT, dm_sparse, ket0_sparse, bit_flip_kraus_nqubits_sparse, doMeasurement
)

# %% [markdown]
# ### Bloch Sphere Visualization of Quantum Noise Channels
#
# Depolarizing channels affect the qubit states \(|0\rangle\) and \(|+\rangle\). Green arrows represent the original states, and red arrows represent the states after the noise.
#
# Generate an array of Kraus operators \(M_i\) for a depolarizing channel.
#
# Write a function that takes as input a single-qubit density matrix and a list of Kraus operators, and returns the density matrix after the channel is applied.
#
# Test your functions by applying the channel to the states \(|0\rangle\) and \(|+\rangle\).

# %%
from qutip import Bloch

p = 0.5
psi = ket0()
rho_in = dm(psi)
print("psi:\n", psi )
print()
print("rho_in:\n", rho_in)
kraus_dep = depolarizing_kraus(p)
print()
print("Kraus operators for depolarizing channel:\n", kraus_dep)
rho_out = apply_kraus(rho_in, kraus_dep)
print()
print("Density matrix after depolarizing channel:\n", rho_out)
v_initial = bloch_vector(rho_in)
v_final = bloch_vector(rho_out)
print()
print("Initial Bloch vector:\n", v_initial)
print()
print("Bloch vector after depolarizing channel:\n", v_final)

b = Bloch()
b.vector_color = ['green','red']
b.add_vectors(v_initial)
b.add_vectors(v_final)
b.title = "Depolarizing Channel"
b.show()
# Out:
# psi:
#  [1.+0.j 0.+0.j]
#
# rho_in:
#  [[1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j]]
#
# Kraus operators for depolarizing channel:
#  [array([[0.79056942+0.j, 0.        +0.j],
#        [0.        +0.j, 0.79056942+0.j]]), array([[0.        +0.j, 0.35355339+0.j],
#        [0.35355339+0.j, 0.        +0.j]]), array([[0.+0.j        , 0.-0.35355339j],
#        [0.+0.35355339j, 0.+0.j        ]]), array([[ 0.35355339+0.j,  0.        +0.j],
#        [ 0.        +0.j, -0.35355339+0.j]])]
#
# Density matrix after depolarizing channel:
#  [[0.75+0.j 0.  +0.j]
#  [0.  +0.j 0.25+0.j]]
#
# Initial Bloch vector:
#  [0. 0. 1.]
#
# Bloch vector after depolarizing channel:
#  [0.  0.  0.5]

# %%
from qutip import Bloch

p = 0.4

psi = ket1()
rho_in = dm(psi)
print("psi:\n", psi )
print()
print("rho_in:\n", rho_in)
kraus_dep = depolarizing_kraus(p)
print()
print("Kraus operators for depolarizing channel:\n", kraus_dep)
rho_out = apply_kraus(rho_in, kraus_dep)
print()
print("Density matrix after depolarizing channel:\n", rho_out)
v_initial = bloch_vector(rho_in)
v_final = bloch_vector(rho_out)
print()
print("Initial Bloch vector:\n", v_initial)
print()
print("Bloch vector after depolarizing channel:\n", v_final)

b = Bloch()
b.vector_color = ['green','red']
b.add_vectors(v_initial)
b.add_vectors(v_final)
b.title = "Depolarizing Channel"
b.show()
# Out:
# psi:
#  [0.+0.j 1.+0.j]
#
# rho_in:
#  [[0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j]]
#
# Kraus operators for depolarizing channel:
#  [array([[0.83666003+0.j, 0.        +0.j],
#        [0.        +0.j, 0.83666003+0.j]]), array([[0.        +0.j, 0.31622777+0.j],
#        [0.31622777+0.j, 0.        +0.j]]), array([[0.+0.j        , 0.-0.31622777j],
#        [0.+0.31622777j, 0.+0.j        ]]), array([[ 0.31622777+0.j,  0.        +0.j],
#        [ 0.        +0.j, -0.31622777+0.j]])]
#
# Density matrix after depolarizing channel:
#  [[0.2+0.j 0. +0.j]
#  [0. +0.j 0.8+0.j]]
#
# Initial Bloch vector:
#  [ 0.  0. -1.]
#
# Bloch vector after depolarizing channel:
#  [ 0.   0.  -0.6]

# %%
from qutip import Bloch

p = 0.7

psi = ket_minus()
rho_in = dm(psi)
print("psi:\n", psi )
print()
print("rho_in:\n", rho_in)
kraus_dep = depolarizing_kraus(p)
print()
print("Kraus operators for depolarizing channel:\n", kraus_dep)
rho_out = apply_kraus(rho_in, kraus_dep)
print()
print("Density matrix after depolarizing channel:\n", rho_out)
v_initial = bloch_vector(rho_in)
v_final = bloch_vector(rho_out)
print()
print("Initial Bloch vector:\n", v_initial)
print()
print("Bloch vector after depolarizing channel:\n", v_final)

b = Bloch()
b.vector_color = ['green','red']
b.add_vectors(v_initial)
b.add_vectors(v_final)
b.title = "Depolarizing Channel"
b.show()
# Out:
# psi:
#  [ 0.70710678+0.j -0.70710678+0.j]
#
# rho_in:
#  [[ 0.5+0.j -0.5-0.j]
#  [-0.5+0.j  0.5+0.j]]
#
# Kraus operators for depolarizing channel:
#  [array([[0.68920244+0.j, 0.        +0.j],
#        [0.        +0.j, 0.68920244+0.j]]), array([[0.        +0.j, 0.41833001+0.j],
#        [0.41833001+0.j, 0.        +0.j]]), array([[0.+0.j        , 0.-0.41833001j],
#        [0.+0.41833001j, 0.+0.j        ]]), array([[ 0.41833001+0.j,  0.        +0.j],
#        [ 0.        +0.j, -0.41833001+0.j]])]
#
# Density matrix after depolarizing channel:
#  [[ 0.5 +0.j -0.15+0.j]
#  [-0.15+0.j  0.5 +0.j]]
#
# Initial Bloch vector:
#  [-1.  0.  0.]
#
# Bloch vector after depolarizing channel:
#  [-0.3  0.   0. ]

# %%
from qutip import Bloch

p = 0.5
psi = ket_plus()
rho_in = dm(psi)
print("psi:\n", psi )
print()
print("rho_in:\n", rho_in)
kraus_dep = depolarizing_kraus(p)
print()
print("Kraus operators for depolarizing channel:\n", kraus_dep)
rho_out = apply_kraus(rho_in, kraus_dep)
print()
print("Density matrix after depolarizing channel:\n", rho_out)
v_initial = bloch_vector(rho_in)
v_final = bloch_vector(rho_out)
print()
print("Initial Bloch vector:", v_initial)
print()
print("Bloch vector after depolarizing channel:", v_final)

b = Bloch()
b.vector_color = ['green','red']
b.add_vectors(v_initial)
b.add_vectors(v_final)
b.title = "Depolarizing Channel"
b.show()
# Out:
# psi:
#  [0.70710678+0.j 0.70710678+0.j]
#
# rho_in:
#  [[0.5+0.j 0.5+0.j]
#  [0.5+0.j 0.5+0.j]]
#
# Kraus operators for depolarizing channel:
#  [array([[0.79056942+0.j, 0.        +0.j],
#        [0.        +0.j, 0.79056942+0.j]]), array([[0.        +0.j, 0.35355339+0.j],
#        [0.35355339+0.j, 0.        +0.j]]), array([[0.+0.j        , 0.-0.35355339j],
#        [0.+0.35355339j, 0.+0.j        ]]), array([[ 0.35355339+0.j,  0.        +0.j],
#        [ 0.        +0.j, -0.35355339+0.j]])]
#
# Density matrix after depolarizing channel:
#  [[0.5 +0.j 0.25+0.j]
#  [0.25+0.j 0.5 +0.j]]
#
# Initial Bloch vector: [1. 0. 0.]
#
# Bloch vector after depolarizing channel: [0.5 0.  0. ]

# %% [markdown]
# ### n-bit Register: Testing the Depolarizing Channel
#
# Test the implementation on a multi-qubit system where the expected result is known. For example, apply the depolarizing channel to the \(|0\rangle\) state for \(n = 4\).

# %%
import numpy as np
import itertools 
p = 0.2
n = 4
psi = ket0
initial_state = np.kron(np.kron(psi(), psi()), np.kron(psi(), psi()))
print("initial_state :\n", initial_state) 
print()
rho_in = np.outer(initial_state, initial_state.conj())
kraus_dep = depolarizing_kraus_nqubits(p, n)
rho_out = apply_kraus(rho_in, kraus_dep)
print("Density matrix:\n", rho_in)
print()
print("Density matrix after depolarizing channel:\n", rho_out)
# Out:
# initial_state :
#  [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#
# Density matrix:
#  [[1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#   0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#   0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#   0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#   0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#   0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#   0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
# ...

# %%
p = 0.2
n = 4
psi = ket_plus
initial_state = np.kron(np.kron(psi(), psi()), np.kron(psi(), psi()))
print("initial_state :\n", initial_state) 
print()
rho_in = np.outer(initial_state, initial_state.conj())
kraus_dep = depolarizing_kraus_nqubits(p, n)
rho_out = apply_kraus(rho_in, kraus_dep)
print("Density matrix:\n", rho_in)
print()
print("Density matrix after depolarizing channel:\n", rho_out)
# Out:
# initial_state :
#  [0.25+0.j 0.25+0.j 0.25+0.j 0.25+0.j 0.25+0.j 0.25+0.j 0.25+0.j 0.25+0.j
#  0.25+0.j 0.25+0.j 0.25+0.j 0.25+0.j 0.25+0.j 0.25+0.j 0.25+0.j 0.25+0.j]
#
# Density matrix:
#  [[0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j
#   0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j
#   0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j]
#  [0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j
#   0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j
#   0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j]
#  [0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j
#   0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j
#   0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j]
#  [0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j
#   0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j
#   0.0625+0.j 0.0625+0.j 0.0625+0.j 0.0625+0.j]
# ...

# %% [markdown]
# ### Fidelity in a Depolarizing Channel
#
# A **depolarizing channel** models noise where a qubit randomly becomes a completely mixed state with a certain probability \(p\).
#
# - The **fidelity** measures how close the final noisy state is to the original state.
# - For a pure state, it is calculated as the overlap between the original state and the noisy state.
#
# As the **depolarizing probability \(p\) increases**, the fidelity **decreases**, showing the increasing deviation of the qubit from its original state.

# %%
import numpy as np
import matplotlib.pyplot as plt


#initial state
alpha = 0.6
beta = np.sqrt(1 - alpha**2)
psi = np.array([alpha, beta], dtype=complex)
psi = normalize_state(psi)
psi = np.array([[1], [0]], dtype=complex)
rho = psi @ psi.conj().T

# Fidelity for a pure state
def fidelity_pure(psi, rho_out):
    return np.real((psi.conj().T @ rho_out @ psi)[0,0])

# Sweep over depolarizing probability p
p_vals = np.linspace(0, 1, 50)
fid_vals = []

for p in p_vals:
    kraus = depolarizing_kraus(p)
    rho_out = apply_kraus(rho, kraus)
    fid_vals.append(fidelity_pure(psi, rho_out))

# Analytical fidelity formula for comparison
fid_analytical = 1 - 2*p_vals/3

# Plot numerical and analytical fidelities
plt.figure(figsize=(7,5))
plt.plot(p_vals, fid_vals, label="Numerical", marker='o', markersize=3)
plt.plot(p_vals, fid_analytical, '--', label="Analytical", color='red')
plt.xlabel("Probability")
plt.ylabel("Fidelity")
plt.title("Fidelity vs Probability")
plt.grid(True)
plt.legend()
plt.show()
