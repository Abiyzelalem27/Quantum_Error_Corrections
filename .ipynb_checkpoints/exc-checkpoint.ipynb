# %%
# !pip install qiskit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...

# %%
import sys
sys.path.append("src")

import numpy as np  # arrays, linear algebra, numerical computing
from qutip import Bloch  # visualization of single-qubit states (Bloch sphere)  
import quantum_error_corrections as qec #  # custom quantum dynamics package 
import matplotlib.pyplot as plt  # plotting and visualizatio
from qiskit.quantum_info import state_fidelity, Statevector, DensityMatrix 
from qiskit import QuantumCircuit #to encode a quantum state for a circuit

# %% [markdown]
# 1. The circuit for encoding the three-qubit bit-flip code is shown in Circuit_1 belows. Verify that this circuit indeed implements such an encoding.

# %%
qc = QuantumCircuit(3)
qc.cx(0, 1)
qc.barrier()
qc.cx(0, 2) 
print("Circuit_1")
print(qc.draw())
# Out:
# Circuit_1
#            ░
# q_0: ──■───░───■──
#      ┌─┴─┐ ░   │
# q_1: ┤ X ├─░───┼──
#      └───┘ ░ ┌─┴─┐
# q_2: ──────░─┤ X ├
#            ░ └───┘

# %%
psi = np.array([0.5, 0.5])  
encoded_psi = qec.operators.encode_3_qubit_bit_flip_code(psi)

print("Encoded 3-qubit state=", encoded_psi)
# Out:
# Encoded 3-qubit state= [0.5+0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0.5+0.j]

# %% [markdown]
# 2) Argue why the three-qubit bit-flip code does not protect against phase-flip errors
#
# Solutions
#
# The 3-qubit bit-flip code encodes:
# |0>_L = |000>
# |1>_L = |111>
# So any logical state becomes:
# |psi>_L = a|000> + b|111>
#
# A phase-flip error is a Z error on one qubit (example: Z1).
#  Z|0> = |0>,   Z|1> = -|1>
#
# Apply Z1 to the encoded state:
#  Z1|psi>_L = a|000> - b|111>
#
# This state is still inside the code space span{|000>,|111>}.
#  Therefore, the phase-flip error does NOT change the bit-flip syndrome,
# so it cannot be detected or corrected.
#
# print("Conclusion: The 3-qubit bit-flip code corrects X (bit-flip) errors, but not Z (phase-flip) errors.")

# %% [markdown]
# to show this in measurement it is very good used the problems we encoded from Problem 1
#
# |psi> = a|0> + b|1>
# |psi>_L = a|000> + b|111> (Logical qubits)
#
# The encoded state is saved in psi_out and used for belows. Phase-flip gate Z (1 qubit) b

# %%
psi = np.array([0.5, 0.5])
encoded = qec.operators.encode_3_qubit_bit_flip_code(psi)
print("Encoded state:\n", encoded)
print()
psi_after_noise = qec.operators.bit_flip_channel_3qubits(encoded, psi)
print("State after noise:\n", psi_after_noise)

error = np.kron(qec.operators.Z, np.kron(qec.operators.I, qec.operators.I))     # Z ⊗ I ⊗ I
errored_state = error @ encoded
print("Errored state=", errored_state)
print()
syndrome = qec.operators.syndrome_measurement_bit_flip(errored_state)
print("Syndrome of errored_state (S1, S2):\n", syndrome)
print()
corrected_state = qec.operators.correct_bit_flip(errored_state)
syndrome = qec.operators.syndrome_measurement_bit_flip(corrected_state)
print("Syndrome of corrected_state (S1, S2)=", syndrome)
print()
print("Corrected state=", corrected_state) 
encoded_psi = qec.operators.encode_3_qubit_bit_flip_code(psi)
print()
corrected_state = qec.operators.correct_bit_flip(errored_state)
print("Corrected state:\n", corrected_state)
# Out:
# Encoded state:
#  [0.5+0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0.5+0.j]
#
# State after noise:
#  [0.35355339+0.j 0.35355339+0.j 0.35355339+0.j 0.35355339+0.j
#  0.35355339+0.j 0.35355339+0.j 0.35355339+0.j 0.35355339+0.j]
# Errored state= [ 0.5+0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j -0.5+0.j]
#
# Syndrome of errored_state (S1, S2):
#  (1, 1)
#
# Syndrome of corrected_state (S1, S2)= (1, 1)
#
# Corrected state= [ 0.5+0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j -0.5+0.j]
#
# Corrected state:
#  [ 0.5+0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j -0.5+0.j]

# %%
psi = np.array([0.5, 0.5])
encoded = qec.operators.encode_3_qubit_bit_flip_code(psi)
print("Encoded state=", encoded)
print()
psi_after_noise = qec.operators.bit_flip_channel_3qubits(encoded, psi)
print("State after noise=", psi_after_noise)

error = np.kron(qec.operators.I, np.kron(qec.operators.Z, qec.operators.I))     # Z ⊗ I ⊗ I
errored_state = error @ encoded
print("Errored state=", errored_state)
print()
syndrome = qec.operators.syndrome_measurement_bit_flip(errored_state)
print("Syndrome of errored_state (S1, S2)=", syndrome)
print()
corrected_state = qec.operators.correct_bit_flip(errored_state)
syndrome = qec.operators.syndrome_measurement_bit_flip(corrected_state)
print("Syndrome of corrected_state (S1, S2)=", syndrome)
print()
print("Corrected state=", corrected_state) 
encoded_psi = qec.operators.encode_3_qubit_bit_flip_code(psi)
print()
corrected_state = qec.operators.correct_bit_flip(errored_state)
print("Corrected state=", corrected_state)
# Out:
# Encoded state= [0.5+0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0.5+0.j]
#
# State after noise= [0.35355339+0.j 0.35355339+0.j 0.35355339+0.j 0.35355339+0.j
#  0.35355339+0.j 0.35355339+0.j 0.35355339+0.j 0.35355339+0.j]
# Errored state= [ 0.5+0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j -0.5+0.j]
#
# Syndrome of errored_state (S1, S2)= (1, 1)
#
# Syndrome of corrected_state (S1, S2)= (1, 1)
#
# Corrected state= [ 0.5+0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j -0.5+0.j]
#
# Corrected state= [ 0.5+0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j -0.5+0.j]

# %%
psi = np.array([0.5, 0.5])
encoded = qec.operators.encode_3_qubit_bit_flip_code(psi)
print("Encoded state=", encoded)
print()
psi_after_noise = qec.operators.bit_flip_channel_3qubits(encoded, psi)
print("State after noise=", psi_after_noise)

error = np.kron(qec.operators.Z, np.kron(qec.operators.I, qec.operators.Z))     # Z ⊗ I ⊗ I
errored_state = error @ encoded
print("Errored state=", errored_state)
print()
syndrome = qec.operators.syndrome_measurement_bit_flip(errored_state)
print("Syndrome of er rored_state (S1, S2)=", syndrome)
print()
corrected_state = qec.operators.correct_bit_flip(errored_state)
syndrome = qec.operators.syndrome_measurement_bit_flip(corrected_state)
print("Syndrome of corrected_state (S1, S2)=", syndrome)
print()
print("Corrected state=", corrected_state) 
encoded_psi = qec.operators.encode_3_qubit_bit_flip_code(psi)
print()
corrected_state = qec.operators.correct_bit_flip(errored_state)
print("Corrected state=", corrected_state)
# Out:
# Encoded state= [0.5+0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0.5+0.j]
#
# State after noise= [0.35355339+0.j 0.35355339+0.j 0.35355339+0.j 0.35355339+0.j
#  0.35355339+0.j 0.35355339+0.j 0.35355339+0.j 0.35355339+0.j]
# Errored state= [0.5+0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0.5+0.j]
#
# Syndrome of er rored_state (S1, S2)= (1, 1)
#
# Syndrome of corrected_state (S1, S2)= (1, 1)
#
# Corrected state= [0.5+0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0.5+0.j]
#
# Corrected state= [0.5+0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j 0.5+0.j]

# %% [markdown]
# Conclusion
# Above all, we see the following points:
# The 3-qubit bit-flip code can correct X (bit-flip) errors.
# It cannot detect or correct Z (phase-flip) errors. It is impossible to detect them in the three-qubit repetition code because the syndrome measurement gives the same result. This happens because Z only changes the relative phase, and the state remains inside the same code space.
# span{∣000⟩,∣111⟩}
